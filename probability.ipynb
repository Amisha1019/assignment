# %% [markdown]
# <a href="https://colab.research.google.com/github/Amisha1019/assignment/blob/main/probability.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def at_least_one_six(trails=10000):
    success = 0
    for _ in range(trials):
        if  6 in [random.randint(1, 6) for _ in range(10)]:
             success += 1
    print(f"estimated probability of at least one 6 in 10 rolls: {success/trials:.4f}")

# %% [markdown]
# # b. rolling two dice to get a sum of 7
# def dice_sum_simulation(trails=10000):
#     count_7 = 0
#     for _ in range(trials):
#         if random.randint(1, 6) + random.randint(1, 6) == 7:
#             count_7 += 1
#     print(f"probability of getting sum 7: {count_7/trails:.4f}")

# %%
import numpy as np

def conditional_probability_simulation(trials=1000):
    colors = ["Red"]*5 + ["Green"]*7 + ["Blue"]*8
    previous = None
    blue_red_count = 0
    blue_total = 0

    for _ in range(trials):
        current = random.choice(colors)
        if previous == "Blue":
            blue_total += 1
            if current == "Red":
                blue_red_count += 1
        previous = current

    if blue_total == 0:
        print("No blue as previous draw occurred.")
    else:
        print(f"P(Red | Previous was Blue) ≈ {blue_red_count / blue_total:.4f}")

# %%
import numpy as np

values = [1, 2, 3]
probabilities = [0.25, 0.35, 0.4]

sample = np.random.choice(values, size=1000, p=probabilities)
print(f"Empirical Mean: {np.mean(sample):.4f}")
print(f"Empirical Variance: {np.var(sample):.4f}")
print(f"Empirical Std Dev: {np.std(sample):.4f}")
# Out:
# Empirical Mean: 2.1580
# Empirical Variance: 0.6290
# Empirical Std Dev: 0.7931

# %%
import matplotlib.pyplot as plt
import seaborn as sns

data = np.random.exponential(scale=5, size=2000)

plt.figure(figsize=(10,5))
sns.histplot(data, kde=True, stat="density", bins=30, color='skyblue')
plt.title('Histogram & PDF of Exponential Distribution (mean=5)')
plt.xlabel('Value')
plt.ylabel('Density')
plt.grid(True)
plt.show()

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Generate 10,000 values from uniform distribution
uniform_data = np.random.uniform(0, 1, 10000)

# Sampling and calculating means
sample_means = []
for _ in range(1000):
    sample = np.random.choice(uniform_data, size=30)
    sample_means.append(np.mean(sample))

# Plotting
plt.figure(figsize=(12,5))

# Original Uniform Distribution
plt.subplot(1,2,1)
sns.histplot(uniform_data, bins=30, kde=False, color='lightgreen')
plt.title("Original Uniform Distribution")

# Distribution of Sample Means
plt.subplot(1,2,2)
sns.histplot(sample_means, bins=30, kde=True, color='salmon')
plt.title("Distribution of Sample Means (CLT)")

plt.tight_layout()
plt.show()
